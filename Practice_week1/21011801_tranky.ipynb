# %% [markdown]
# # Import libraries

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read and show images

# %%
path = './img/00750.jpeg'
img = cv2.imread(path,0)
img
# ''' 
# ảnh sẽ là một ma trận 
# ''
# Out:
# array([[125, 125, 125, ...,  94,  96, 105],
#        [125, 125, 125, ...,  94, 101, 109],
#        [125, 125, 125, ...,  95, 104, 109],
#        ...,
#        [114, 114, 114, ..., 148, 123,  94],
#        [114, 114, 114, ..., 147, 122,  93],
#        [114, 114, 114, ..., 147, 128,  99]], dtype=uint8)

# %%
# plt.imshow(img[:,:,::-1]) # đảo ngược kênh màu thành màu RGB
plt.imshow(img) # đảo ngược kênh màu thành màu RGB
img.shape
# Out:
# (611, 450)

# %% [markdown]
# # Show size of image

# %%
# H, W, C = img.shape
# print("Height: ", H)
# print("Width: ", W)
# print("Channel: ", C)
#Height , Width , Channel

# %%
print("Img size: ", img.size) # size = Height * Width * Channel
# Out:
# Img size:  274950

# %% [markdown]
# # Show type of image

# %%
img.dtype
# '''
#     Kiểu dữ liệu của ảnh
# '''
# Out:
# dtype('uint8')

# %% [markdown]
# # imread() with different color format
# - IMREAD_ANYCOLOR=4
# - IMREAD_ANYDEPTH = 2
# - IMREAD_COLOR=1
# - IMREAD_GRAYSCALE = 0
# - IMREAD_LOAD_GDAL = 8
# - IMREAD_UNCHANGED = -1

# %%
def read_img_option(path, option):
    img= cv2.imread(path,option)
    return img
def show_img(img):
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
img_anycolor=read_img_option(path, cv2.IMREAD_ANYCOLOR)
show_img(img_anycolor)

# %%
img_anydepth=read_img_option(path, cv2.IMREAD_ANYDEPTH)
show_img(img_anydepth)

# %%
img_color=read_img_option(path, cv2.IMREAD_COLOR)
show_img(img_color)

# %%
img_grayscale=read_img_option(path, cv2.IMREAD_GRAYSCALE)
show_img(img_grayscale)

# %%
img_load_gdal=read_img_option(path, cv2.IMREAD_LOAD_GDAL)
show_img(img_load_gdal)

# %%
img_unchanged=read_img_option(path, cv2.IMREAD_UNCHANGED)
show_img(img_unchanged)

# %% [markdown]
# # Make a random image

# %%
import os
randomByteArray = bytearray(os.urandom(120000))
flatNumpyArray = np.array(randomByteArray)
type(flatNumpyArray)
# Out:
# numpy.ndarray

# %%
flatNumpyArray.shape
# Out:
# (120000,)

# %%
flatNumpyArray[5:20]
# Out:
# array([126,  45,  22, 179, 138, 208, 251,  22, 111, 205,  63, 234, 110,
#         73, 171], dtype=uint8)

# %%
np.max(flatNumpyArray)
# Out:
# np.uint8(255)

# %%
grayImage= flatNumpyArray.reshape(300,400)
show_img(grayImage)

# %%
bgrImage= flatNumpyArray.reshape(100,400,3)
show_img(bgrImage[:,:,::-1])

# %%
array=np.random.randint(0,256,120000)
grayImage= array.reshape(300,400)
show_img(grayImage)

# %% [markdown]
# # Resizing images

# %%
h,w,_ = img.shape
resized = cv2.resize(img,(50,50))
show_img(resized[:,:,::-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 h,w,_ = img.shape
#       2 resized = cv2.resize(img,(50,50))
#       3 show_img(resized[:,:,::-1])
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
new_w =500
aspect_ratio = h/w
new_h = int(new_w*aspect_ratio)
print(new_h)

# %%
resized = cv2.resize(img,(new_w,new_h))
show_img(resized[:,:,::-1])

# %% [markdown]
# # END
